# %%
import pandas as pd
from IPython.display import display, HTML

# load all sentences that occured 8 times or more
sentences_df = pd.read_csv('data/BookCorpus/sentences_counted_8+.csv')

# load "bad words"
bad_words = pd.read_csv('https://raw.githubusercontent.com/LDNOOBW/List-of-Dirty-Naughty-Obscene-and-Otherwise-Bad-Words/master/en',header=None)
bad_words.columns = ['word']

# compute bad word flag
bad_words_list = bad_words.word.tolist()
sentences_df['contains_bad_word'] = sentences_df.sentence.str.contains(' | '.join(bad_words_list))

# compute space count (sentence length)
sentences_df['space_count'] = sentences_df.sentence.str.count(' ')

# %% [markdown]
# # Overview and samples

# %%
# most common sentences with at least 8 spaces
sentences_df[(sentences_df.space_count>7)].head(10)
# Out:
#       Unnamed: 0                                           sentence     n  \
# 494          494              `` what 's that supposed to mean ? ''  1408
# 536          536  thank you for respecting the hard work of this...  1345
# 555          555  this ebook may not be re-sold or given away to...  1302
# 625          625  if you would like to share this book with anot...  1193
# 674          674                   `` what are you going to do ? ''  1113
# 1003        1003  if youre reading this book and did not purchas...   788
# 1053        1053                `` what the hell are you doing ? ''   760
# 1056        1056   `` i do n't know what you 're talking about . ''   759
# 1121        1121                    `` why did n't you tell me ? ''   721
# 1468        1468                    `` what are we going to do ? ''   568
#
#       contains_bad_word  space_count
# 494               False            8
# 536               False           10
# 555               False           12
# 625               False           20
# 674               False            8
# 1003              False           31
# 1053              False            8
# 1056              False           11
# 1121              False            8
# 1468              False            8

# %%
# a closer look at common copyright sentences
sentences_df[sentences_df.sentence.str.contains('copyright')].head(10)
# Out:
#         Unnamed: 0                                           sentence    n  \
# 10068        10068  this book remains the copyrighted property of ...  111
# 10340        10340  although this is a free book , it remains the ...  109
# 26176        26176  without limiting the rights under copyright re...   49
# 66153        66153  please do not participate in or encourage pira...   22
# 76446        76446  it remains the copyrighted property of the aut...   19
# 81529        81529  the stories , articles and illustrations conta...   18
# 97707        97707  no part of this publication may be copied , re...   16
# 98227        98227  this book contains material protected under in...   16
# 121571      121571  although this is a free book , it remains the ...   13
# 122441      122441  although this is a free book , it remains the ...   13
#
#         contains_bad_word  space_count
# 10068               False           22
# 10340               False           30
# 26176               False           67
# 66153               False           17
# 76446               False           23
# 81529               False           24
# 97707               False           34
# 98227               False           13
# 121571              False           36
# 122441              False           31

# %%
# random sample of common sentences with at least 7 spaces
sentences_df[(sentences_df.space_count>7)].sample(10).sort_values(by='n',ascending=False)
# Out:
#         Unnamed: 0                                           sentence   n  \
# 46662        46662                   what the hell am i going to do ?  30
# 62161        62161                  `` what would you have of me ? ''  23
# 122132      122132               i was n't sure how i felt about it .  13
# 142549      142549                        `` you got it , '' i said .  11
# 181383      181383                      `` you do n't want me to ? ''   9
# 225814      225814            `` do you have a better suggestion ? ''   8
# 231134      231134  just beneath that silk , however , he thought ...   8
# 230675      230675  `` in my head , sofia , there 's always music ...   8
# 219992      219992                   `` does it feel good , baby ? ''   8
# 222095      222095           not that he would have had to look far .   8
#
#         contains_bad_word  space_count
# 46662               False            8
# 62161               False            8
# 122132              False            9
# 142549              False            8
# 181383              False            8
# 225814              False            8
# 231134              False           15
# 230675              False           12
# 219992              False            8
# 222095              False            9

# %%
# random sample of all common sentences
sentences_df.sample(10).sort_values(by='n',ascending=False)
# Out:
#         Unnamed: 0                                           sentence   n  \
# 45299        45299                                          problem .  31
# 51151        51151                             `` yeah , i got that .  28
# 53261        53261                                      howie asked .  27
# 63403        63403                              just keep breathing .  23
# 80922        80922                       `` that about covers it . ''  18
# 140459      140459                                    jeff inquired .  12
# 142775      142775                                     `` groovy . ''  11
# 207714      207714                             she would n't listen .   8
# 204858      204858                              i felt pity for him .   8
# 232035      232035  just like that , she knew what this little mak...   8
#
#         contains_bad_word  space_count
# 45299               False            1
# 51151               False            6
# 53261               False            2
# 63403               False            3
# 80922               False            6
# 140459              False            2
# 142775              False            3
# 207714              False            4
# 204858              False            5
# 232035              False           13

# %% [markdown]
# # Lite gender analysis

# %%
# most common sentences containing "he"
sentences_df[(sentences_df.space_count>7)&(sentences_df.sentence.str.contains(' he '))].head(10)
# Out:
#        Unnamed: 0                           sentence    n  contains_bad_word  \
# 1503         1503       `` i 'm sorry , '' he said .  555              False
# 2657         2657    `` i do n't know , '' he said .  343              False
# 5570         5570       `` i love you , '' he said .  184              False
# 8543         8543      `` what did he do to you ? ''  127              False
# 8626         8626     `` do n't worry , '' he said .  126              False
# 9043         9043  `` i love you , '' he whispered .  121              False
# 9157         9157    `` do you know where he is ? ''  120              False
# 9666         9666    `` you 're right , '' he said .  115              False
# 10562       10562  `` i 'm sorry , '' he whispered .  107              False
# 11811       11811       `` it 's okay , '' he said .   97              False
#
#        space_count
# 1503             8
# 2657             9
# 5570             8
# 8543             8
# 8626             8
# 9043             8
# 9157             8
# 9666             8
# 10562            8
# 11811            8

# %%
# most common sentences containing "she"
sentences_df[(sentences_df.space_count>7)&(sentences_df.sentence.str.contains(' she '))].head(10)
# Out:
#        Unnamed: 0                             sentence    n  \
# 1996         1996        `` i 'm sorry , '' she said .  443
# 3041         3041     `` i do n't know , '' she said .  306
# 4265         4265   `` i 'm sorry , '' she whispered .  231
# 8041         8041   `` i love you , '' she whispered .  134
# 9077         9077        `` i love you , '' she said .  121
# 9415         9415     `` you 're right , '' she said .  117
# 9780         9780         `` i 'm fine , '' she said .  114
# 9978         9978        `` it 's okay , '' she said .  112
# 13399       13399          `` i ca n't , '' she said .   87
# 15938       15938  `` thank you , '' she said softly .   75
#
#        contains_bad_word  space_count
# 1996               False            8
# 3041               False            9
# 4265               False            8
# 8041               False            8
# 9077               False            8
# 9415               False            8
# 9780               False            8
# 9978               False            8
# 13399              False            8
# 15938              False            8

# %% [markdown]
# # Lite "bad word" analysis

# %%
# most common sentences with "bad words"
sentences_df[(sentences_df.contains_bad_word)&(sentences_df.space_count>4)].head(10)
# Out:
#        Unnamed: 0                    sentence    n  contains_bad_word  \
# 2340         2340       `` what the fuck ? ''  383               True
# 3809         3809      `` son of a bitch ! ''  256               True
# 3908         3908           `` oh , shit . ''  250               True
# 4472         4472        shit , shit , shit .  222               True
# 5560         5560      `` son of a bitch . ''  184               True
# 7108         7108           `` oh , shit ! ''  149               True
# 7794         7794  `` you son of a bitch ! ''  137               True
# 10298       10298       `` shit , '' i said .  109               True
# 11304       11304        i suck in a breath .  101               True
# 11649       11649        shit , shit , shit !   98               True
#
#        space_count
# 2340             5
# 3809             6
# 3908             5
# 4472             5
# 5560             6
# 7108             5
# 7794             7
# 10298            6
# 11304            5
# 11649            5

# %%
# random sentences with "bad words"
sentences_df[(sentences_df.contains_bad_word)].sample(10).sort_values(by='n',ascending=False)
# Out:
#         Unnamed: 0                                           sentence    n  \
# 5306          5306                                      the bastard .  192
# 13283        13283                                       `` bastard .   88
# 19634        19634                                        holy fuck !   63
# 24915        24915                                     `` you bitch !   51
# 27169        27169                                  `` smart ass . ''   48
# 157978      157978                                     `` your cock .   10
# 181326      181326                                  `` aw , fuck . ''    9
# 215952      215952  `` yeah , and i 'll do it again if you do n't ...    8
# 205718      205718                              `` piece of shit . ''    8
# 220311      220311                                 your ass is mine .    8
#
#         contains_bad_word  space_count
# 5306                 True            2
# 13283                True            2
# 19634                True            2
# 24915                True            3
# 27169                True            4
# 157978               True            3
# 181326               True            5
# 215952               True           19
# 205718               True            5
# 220311               True            4

# %%
# common longer sentences with "bad words"
sentences_df[(sentences_df.contains_bad_word) & (sentences_df.space_count>7)].head(10)
# Out:
#        Unnamed: 0                                          sentence   n  \
# 24378       24378       `` what the fuck are you talking about ? ''  52
# 25302       25302               `` what the fuck are you doing ? ''  51
# 40642       40642             `` you scared the shit out of me . ''  34
# 46609       46609                   `` you 're so full of shit . ''  30
# 52958       52958                   `` you are so full of shit . ''  27
# 54045       54045  `` what the fuck do you think you 're doing ? ''  26
# 55438       55438          `` what the fuck are you doing here ? ''  26
# 56448       56448                you scared the shit out of me ! ''  25
# 64022       64022                 `` what the fuck is going on ? ''  23
# 64052       64052                you scared the shit out of me . ''  23
#
#        contains_bad_word  space_count
# 24378               True            9
# 25302               True            8
# 40642               True            9
# 46609               True            8
# 52958               True            8
# 54045               True           11
# 55438               True            9
# 56448               True            8
# 64022               True            8
# 64052               True            8
