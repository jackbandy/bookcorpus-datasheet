# %%
import pandas as pd
from IPython.display import display, HTML

# load all sentences that occured 10 times or more
sentences_df = pd.read_csv('data/BookCorpus/sentences_counted_8+.csv')

# load "bad words"
bad_words = pd.read_csv('https://raw.githubusercontent.com/LDNOOBW/List-of-Dirty-Naughty-Obscene-and-Otherwise-Bad-Words/master/en',header=None)
bad_words.columns = ['word']

# compute bad word flag
bad_words_list = bad_words.word.tolist()
sentences_df['contains_bad_word'] = sentences_df.sentence.str.contains(' | '.join(bad_words_list))

# compute space count (sentence length)
sentences_df['space_count'] = sentences_df.sentence.str.count(' ')

# %%
# sample of all sentences occuring 8+ times
sentences_df.sample(10).sort_values(by='n',ascending=False)
# Out:
#         Unnamed: 0                                           sentence    n  \
# 8993          8993                              he did n't hesitate .  122
# 131721      131721                             and what do you know .   12
# 143651      143651                                the man whispered .   11
# 149718      149718                                    oh , but i do .   11
# 165355      165355                                   jane asked him .   10
# 169956      169956                                longbow suggested .   10
# 180998      180998                                    ms. messenger .    9
# 228091      228091                              she 's all right . ''    8
# 208685      208685                                              xoe ?    8
# 237554      237554  a shift that had consisted of walking the pris...    8
#
#         contains_bad_word  space_count
# 8993                False            4
# 131721              False            5
# 143651              False            3
# 149718              False            5
# 165355              False            3
# 169956              False            2
# 180998              False            2
# 228091              False            5
# 208685              False            1
# 237554              False           22

# %%
# most common sentences containing "he"
sentences_df[sentences_df.sentence.str.contains(' he ')].head(10)
# Out:
#       Unnamed: 0                 sentence     n  contains_bad_word  \
# 374          374     `` no , '' he said .  1763              False
# 541          541      `` where is he ? ''  1331              False
# 632          632    `` yes , '' he said .  1177              False
# 807          807            where is he ?   970              False
# 853          853         but he did n't .   914              False
# 999          999  `` what did he say ? ''   793              False
# 1112        1112           where was he ?   728              False
# 1400        1400             and he did .   589              False
# 1442        1442      what was he doing ?   576              False
# 1481        1481   `` okay , '' he said .   562              False
#
#       space_count
# 374             6
# 541             5
# 632             6
# 807             3
# 853             4
# 999             6
# 1112            3
# 1400            3
# 1442            4
# 1481            6

# %%
# most common sentences containing "she"
sentences_df[sentences_df.sentence.str.contains(' she ')].head(10)
# Out:
#       Unnamed: 0                  sentence     n  contains_bad_word  \
# 522          522      `` where is she ? ''  1358              False
# 568          568     `` no , '' she said .  1274              False
# 719          719    `` yes , '' she said .  1070              False
# 966          966            where is she ?   812              False
# 1358        1358           where was she ?   608              False
# 1462        1462   `` okay , '' she said .   572              False
# 1498        1498        `` how is she ? ''   557              False
# 1581        1581         but she did n't .   533              False
# 1650        1650  `` what did she say ? ''   516              False
# 1836        1836       `` is she okay ? ''   472              False
#
#       space_count
# 522             5
# 568             6
# 719             6
# 966             3
# 1358            3
# 1462            6
# 1498            5
# 1581            4
# 1650            6
# 1836            5

# %%
# common sentences about copyright
sentences_df[sentences_df.sentence.str.contains('copyright')].head(10)
# Out:
#         Unnamed: 0                                           sentence    n  \
# 10068        10068  this book remains the copyrighted property of ...  111
# 10340        10340  although this is a free book , it remains the ...  109
# 26176        26176  without limiting the rights under copyright re...   49
# 66153        66153  please do not participate in or encourage pira...   22
# 76446        76446  it remains the copyrighted property of the aut...   19
# 81529        81529  the stories , articles and illustrations conta...   18
# 97707        97707  no part of this publication may be copied , re...   16
# 98227        98227  this book contains material protected under in...   16
# 121571      121571  although this is a free book , it remains the ...   13
# 122441      122441  although this is a free book , it remains the ...   13
#
#         contains_bad_word  space_count
# 10068               False           22
# 10340               False           30
# 26176               False           67
# 66153               False           17
# 76446               False           23
# 81529               False           24
# 97707               False           34
# 98227               False           13
# 121571              False           36
# 122441              False           31

# %%
# random sentences with "bad words"
sentences_df[(sentences_df.contains_bad_word)].sample(10).sort_values(by='n',ascending=False)
# Out:
#         Unnamed: 0                            sentence   n  contains_bad_word  \
# 16799        16799                     `` asshole ! ''  72               True
# 23725        23725                         ah , fuck .  54               True
# 26130        26130        `` who the fuck are you ? ''  49               True
# 50164        50164                    it 's just sex .  28               True
# 58508        58508             what the fuck is that ?  24               True
# 69826        69826                 `` you 're an ass .  21               True
# 79965        79965              `` fuck if i know . ''  19               True
# 85715        85715  `` you scared the shit out of me .  18               True
# 89295        89295                `` he 's an ass . ''  17               True
# 137218      137218             `` shut up , bitch . ''  12               True
#
#         space_count
# 16799             3
# 23725             3
# 26130             7
# 50164             4
# 58508             5
# 69826             5
# 79965             6
# 85715             8
# 89295             6
# 137218            6

# %%
# common longer sentences with "bad words"
sentences_df[(sentences_df.contains_bad_word) & (sentences_df.space_count>7)].head(10)
# Out:
#        Unnamed: 0                                          sentence   n  \
# 24378       24378       `` what the fuck are you talking about ? ''  52
# 25302       25302               `` what the fuck are you doing ? ''  51
# 40642       40642             `` you scared the shit out of me . ''  34
# 46609       46609                   `` you 're so full of shit . ''  30
# 52958       52958                   `` you are so full of shit . ''  27
# 54045       54045  `` what the fuck do you think you 're doing ? ''  26
# 55438       55438          `` what the fuck are you doing here ? ''  26
# 56448       56448                you scared the shit out of me ! ''  25
# 64022       64022                 `` what the fuck is going on ? ''  23
# 64052       64052                you scared the shit out of me . ''  23
#
#        contains_bad_word  space_count
# 24378               True            9
# 25302               True            8
# 40642               True            9
# 46609               True            8
# 52958               True            8
# 54045               True           11
# 55438               True            9
# 56448               True            8
# 64022               True            8
# 64052               True            8
